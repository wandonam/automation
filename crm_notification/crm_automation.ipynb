# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df = pd.read_excel(f'./data/raw_2024.xlsx')

# %%
today = datetime.today()

# %%
three_month_ago = today - timedelta(days=90)

# %%
df['결제일']
# Out:
# datetime.datetime(2024, 4, 16, 17, 41, 43, 980300)

# %%
df_filtered = df[df['결제일'] >= three_month_ago]

# %%
df_filtered = df[df['매출처'] == '자사몰']

# %%
df_filtered
# Out:
#              결제일                 출고일  매출처          쇼핑몰 주문번호      상품코드  \
# 43    2024-01-01 2024-01-01 11:03:00  자사몰  20240101-0000146  P000000R
# 44    2024-01-01 2024-01-01 17:30:00  자사몰  20240101-0000257  P00000DP
# 45    2024-01-01 2024-01-01 23:31:00  자사몰  20240101-0000442  P00000IP
# 46    2024-01-01 2024-01-01 15:58:00  자사몰  20240101-0000222  P00000BK
# 47    2024-01-01 2024-01-01 20:36:00  자사몰  20240101-0000375  P00000BA
# ...          ...                 ...  ...               ...       ...
# 14340 2024-07-14 2024-07-14 20:46:27  자사몰  20240714-0000271  P00000JZ
# 14341 2024-07-14 2024-07-14 21:01:08  자사몰  20240714-0000286  P00000JZ
# 14342 2024-07-14 2024-07-14 21:40:34  자사몰  20240714-0000303  P00000JZ
# 14343 2024-07-14 2024-07-14 00:41:53  자사몰  20240714-0000011  P00000JZ
# 14344 2024-07-14 2024-07-14 22:52:26  자사몰  20240714-0000332  P00000JD
#
#                옵션코드  수량  총\n결제가   배송비  추가\n배송비  ...     원가 총\n배송비\n 배송비\n원가  \
# ...
